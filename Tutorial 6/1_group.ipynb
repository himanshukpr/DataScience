# %%
import pandas as pd
df = pd.read_csv('data.csv')

g = df.groupby('City')

# for city, group in g:
#     print(f'City: {city}')
#     print(group)

# g.get_group('Delhi')
g.describe()
# Out:
#           Temperature (C)                                                     \
#                     count       mean       std   min   25%   50%   75%   max
# City
# Bangalore            15.0  28.666667  4.592955  23.0  25.0  28.0  33.0  35.0
# Delhi                15.0  29.266667  4.283968  23.0  26.0  30.0  33.0  35.0
# Mumbai               15.0  27.733333  4.131182  20.0  24.5  29.0  30.5  34.0
#
#           Wind Speed (km/h)
#                       count       mean       std  min   25%   50%   75%   max
# City
# Bangalore              15.0  13.066667  3.788454  7.0  10.5  12.0  16.0  20.0
# Delhi                  15.0  13.866667  5.475486  5.0   9.5  14.0  19.0  20.0
# Mumbai                 15.0  12.933333  4.905779  6.0   8.0  14.0  17.0  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# City
# Bangalore    Axes(0.125,0.11;0.775x0.77)
# Delhi        Axes(0.125,0.11;0.775x0.77)
# Mumbai       Axes(0.125,0.11;0.775x0.77)
# dtype: object
