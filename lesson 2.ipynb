# %%
import pandas as pd

df = pd.read_excel('items.xlsx', sheet_name = 'Sheet1')

# with using the tuples and the list
# data = [(1,'a'),(2,'b')]
# col = ['col1', 'col2']
# df = pd.DataFrame(data, columns = col)

# with the excel
# df = pd.read_excel('data.xlsx', sheet_name='Sheet1')

# Creating a DataFrame from a List of Dictionaries
# data = [{'col1': 1, 'col2': 'A'}, {'col1': 2, 'col2': 'B', 'col3': 'X'}, {'col1': 3, 'col2': 'C'}]
# df = pd.DataFrame(data)

# data = {
#     'col1':[1,2,3,4],
#     'col2':['a','b','c','d']
# }

# df = pd.DataFrame(data)
# df.set_index('col1')

# %%
# df[df.temperature==df.temperature.min()]
# df['col1'].mean()

# %%
df
# Out:
#                           Name  Calories  \
# 0                     Espresso       3.0
# 1           Espresso Macchiato      35.0
# 2                    Americano       3.0
# 3                      Cortado      72.0
# 4                        Latte     243.0
# 5                   Cappuccino     149.0
# 6                Filter Coffee       3.0
# 7                   Chai Latte     346.0
# 8                 Matcha Latte     205.0
# 9         Vanilla Matcha Latte     277.0
# 10  Tea (Green, Herbal, Black)       1.0
# 11                  Iced Latte     150.0
# 12          Iced Vanilla Latte     222.0
# 13                   Cold Brew       3.0
# 14              Iced Americano       3.0
# 15                Coffee Shake     323.0
# 16             Iced Chai Latte     224.0
# 17           Iced Matcha Latte     112.0
# 18   Iced Vanilla Matcha Latte     184.0
# 19                  Herb Tonic     187.0
# 20                Green Shield     190.0
# 21                   Feel Good     184.0
# 22            Joe's Green Mile     273.0
# 23              Joe's Identity      71.0
# 24           Hydration Station     184.0
# 25                 Go Away Doc     264.0
# 26             Prince of Green      65.0
# 27                    Iron Man     243.0
# 28                 Stress Down     250.0
# 29                 Green Sport     177.0
# 30                 Green Tonic      73.0
# 31                  Pick Me Up     258.0
# 32             Burrata Caprese       NaN
# 33            Mushroom-Truffle       NaN
# 34           Caponata Crostini       NaN
# 35                    The Hass       NaN
# 36         Lemon Ginger Zinger       NaN
# 37                         ABC       NaN
# 38           Hair Growth Juice       NaN
# 39         Cholesterol Reducer       NaN
# 40                Anti-Fatigue       NaN
# 41               The Refresher       NaN
# 42                The Cleanser       NaN
# 43                  Tim’s Bowl       NaN
# 44               The Keto Bowl       NaN
#
#                                           Ingredients
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Turmeric, Ginger, Pineapple, Carrot, Black Pep...
# 20             Kale, Ginger, Cucumber, Spinach, Apple
# 21             Carrot, Turmeric, Ginger, Lemon, Apple
# 22               Spinach, Kiwi, Avocado, Lemon, Apple
# 23             Kale, Celery, Spinach, Lemon, Cucumber
# 24       Coconut Water, Lemon, Spinach, Ginger, Apple
# 25                              Carrot, Ginger, Apple
# 26                         Pineapple, Lemon, Cucumber
# 27                            Kiwi, Strawberry, Apple
# 28                          Strawberry, Ginger, Apple
# 29                         Cucumber, Pineapple, Apple
# 30                             Kale, Celery, Cucumber
# 31                          Strawberry, Banana, Apple
# 32  Burrata on toasted bread, sun-dried tomato, pe...
# 33  Grilled mushrooms, white truffle oil, tomato c...
# 34  Sicilian eggplant, peppers, Parmesan, multigra...
# 35  Hass avocado, cherry tomato confit, bocconcini...
# 36                 Green apple, carrot, ginger, lemon
# 37                                Apple, beet, carrot
# 38                Green apple, carrot, mint, cinnamon
# 39                    Sweetlime, celery, lime, ginger
# 40                Carrot, beet, apple, lemon, spinach
# 41                  Pineapple, cucumber, celery, mint
# 42                   Watermelon, rosemary, chia seeds
# 43  Brown rice, grilled pineapple, Hass avocado, b...
# 44  Cauli rice, sautéed veggies, Hass avocado, Gou...

# %%
# df[df.Calories==df.Calories.max()]
df[df.Name == 'ABC']
# Out:
#    Name  Calories          Ingredients
# 37  ABC       NaN  Apple, beet, carrot
